# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os

# %%
nomes = pd.read_csv('./saidas/nameRepo.txt', names=['Nome'])
commits = pd.read_csv('./saidas/numCommits.txt', names=['Número de Commits'])
linguagem = pd.read_csv('./saidas/lang.txt', names=['Linguagem'])

# %%
df = nomes.join([linguagem, commits])

# %% [markdown]
# # Boxplots

# %%
plt.boxplot(df['Número de Commits'], labels=['Geral'])
plt.show()

# %%
javascript = df['Número de Commits'][df['Linguagem'] == '1_Javascript']
python = df['Número de Commits'][df['Linguagem'] == '2_Python']
java = df['Número de Commits'][df['Linguagem'] == '3_Java']
go = df['Número de Commits'][df['Linguagem'] == '4_GO']
cpp = df['Número de Commits'][df['Linguagem'] == '5_C++']

data = [javascript, python, java, go, cpp]
plt.subplot().boxplot(data, labels=['Javascript', 'Python', 'Java', 'GO', 'C++'])
plt.show()

# %% [markdown]
# # Mapa de Calor

# %%
directory = '/Users/brunovieira/Desktop/REPOSITORIOS/saidas/heatmap/'
heatmapDF = pd.DataFrame(columns=['Linguagem', 'Repositório', 'Local de Mudança'])

for lang in os.listdir(directory):
    if lang != '.DS_Store':
        for repo in os.listdir(directory+lang):
            if repo != '.DS_Store':
                diff = open(directory+lang+'/'+repo+'/diff.txt', "r")
                nRows = np.array(pd.read_csv(directory+lang+'/'+repo+'/nRows.csv', names=['# de linhas']))
                diffStr = diff.read()
                diffSplit = re.split("diff --git", diffStr)
                diffSplit.pop(0)
                
                rowsOfDiff = []
                for i in range(len(diffSplit)):
                    a = re.findall(r'@@[ X][-](.*?)[ X][+]', diffSplit[i])
                    b = []
                    for j in a:
                        c = int(float(j.replace(',','.')))
                        b.append(c)
                    rowsOfDiff.append(b)
                
                heatmapChanges = []
                for i in range(len(rowsOfDiff)):
                    for j in range(len(rowsOfDiff[i])):
                        if nRows[i] == 0:
                            heatmapChanges.append(0)
                        elif (rowsOfDiff[i][j] / nRows[i]) > 1:
                            heatmapChanges.append(1)
                        else:
                            heatmapChanges.append(np.float(rowsOfDiff[i][j] / nRows[i]))
                            
                df = pd.DataFrame(columns=['Linguagem', 'Repositório', 'Local de Mudança'])
                df['Local de Mudança'] = heatmapChanges
                df['Repositório'] = repo
                df['Linguagem'] = lang
                heatmapDF = heatmapDF.append(df)

# %%
heatmapDF['x10'] = np.round(heatmapDF['Local de Mudança'] * 10)
heatmapDF['x100'] = np.round(heatmapDF['Local de Mudança'] * 100)
heatmapDF
# Out:
#     Linguagem   Repositório  Local de Mudança   x10   x100
# 0        4_GO     syncthing          0.567797   6.0   57.0
# 1        4_GO     syncthing          0.542373   5.0   54.0
# 2        4_GO     syncthing          0.949153   9.0   95.0
# 3        4_GO     syncthing          0.044248   0.0    4.0
# 4        4_GO     syncthing          0.789474   8.0   79.0
# 5        4_GO     syncthing          0.991228  10.0   99.0
# 6        4_GO     syncthing          0.203540   2.0   20.0
# 7        4_GO     syncthing          0.247788   2.0   25.0
# 8        4_GO     syncthing          0.300885   3.0   30.0
# 9        4_GO     syncthing          0.336283   3.0   34.0
# 10       4_GO     syncthing          0.371681   4.0   37.0
# 11       4_GO     syncthing          0.415929   4.0   42.0
# 12       4_GO     syncthing          0.460177   5.0   46.0
# 13       4_GO     syncthing          0.044248   0.0    4.0
# 14       4_GO     syncthing          1.000000  10.0  100.0
# 15       4_GO     syncthing          0.903509   9.0   90.0
# 16       4_GO     syncthing          0.008772   0.0    1.0
# 17       4_GO     syncthing          0.964912  10.0   96.0
# 18       4_GO     syncthing          0.027273   0.0    3.0
# 19       4_GO     syncthing          0.918182   9.0   92.0
# 20       4_GO     syncthing          0.127273   1.0   13.0
# 21       4_GO     syncthing          0.081818   1.0    8.0
# 22       4_GO     syncthing          0.027523   0.0    3.0
# 23       4_GO     syncthing          0.075472   1.0    8.0
# 24       4_GO     syncthing          0.094340   1.0    9.0
# 25       4_GO     syncthing          0.141509   1.0   14.0
# 26       4_GO     syncthing          0.179245   2.0   18.0
# 27       4_GO     syncthing          0.707547   7.0   71.0
# 28       4_GO     syncthing          0.853333   9.0   85.0
# 29       4_GO     syncthing          0.906667   9.0   91.0
# ..        ...           ...               ...   ...    ...
# 177  2_Python  scikit-learn          1.000000  10.0  100.0
# 178  2_Python  scikit-learn          1.000000  10.0  100.0
# 179  2_Python  scikit-learn          0.366337   4.0   37.0
# 180  2_Python  scikit-learn          0.386139   4.0   39.0
# 181  2_Python  scikit-learn          0.291667   3.0   29.0
# 182  2_Python  scikit-learn          0.836735   8.0   84.0
# 183  2_Python  scikit-learn          0.908163   9.0   91.0
# 184  2_Python  scikit-learn          0.959184  10.0   96.0
# 185  2_Python  scikit-learn          0.282828   3.0   28.0
# 186  2_Python  scikit-learn          0.897959   9.0   90.0
# 187  2_Python  scikit-learn          0.948980   9.0   95.0
# 188  2_Python  scikit-learn          0.916667   9.0   92.0
# 189  2_Python  scikit-learn          0.958333  10.0   96.0
# 190  2_Python  scikit-learn          0.936170   9.0   94.0
# 191  2_Python  scikit-learn          0.907216   9.0   91.0
# 192  2_Python  scikit-learn          0.301075   3.0   30.0
# 193  2_Python  scikit-learn          0.322581   3.0   32.0
# 194  2_Python  scikit-learn          0.978261  10.0   98.0
# 195  2_Python  scikit-learn          0.097826   1.0   10.0
# 196  2_Python  scikit-learn          0.119565   1.0   12.0
# 197  2_Python  scikit-learn          0.978261  10.0   98.0
# 198  2_Python  scikit-learn          0.326087   3.0   33.0
# 199  2_Python  scikit-learn          0.750000   8.0   75.0
# 200  2_Python  scikit-learn          0.770833   8.0   77.0
# 201  2_Python  scikit-learn          0.791667   8.0   79.0
# 202  2_Python  scikit-learn          0.812500   8.0   81.0
# 203  2_Python  scikit-learn          0.540816   5.0   54.0
# 204  2_Python  scikit-learn          0.663265   7.0   66.0
# 205  2_Python  scikit-learn          0.314607   3.0   31.0
# 206  2_Python  scikit-learn          0.337079   3.0   34.0
#
# [18394 rows x 5 columns]

# %% [markdown]
# ## Geral

# %%
data10 = np.empty([11, 1])
for i in range(11):
    data10[i] = heatmapDF['x10'][heatmapDF['x10'] == i].count()


    
ax = sns.heatmap(data10, cmap="YlOrRd", yticklabels=5, xticklabels=False)

# %%
data100 = np.empty([101, 1])
for i in range(101):
    data100[i] = heatmapDF['x100'][heatmapDF['x100'] == i].count()
    
bx = sns.heatmap(data100, cmap="YlOrRd", yticklabels=50, xticklabels=False)
